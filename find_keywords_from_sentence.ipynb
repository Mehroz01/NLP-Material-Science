# %%
from __future__ import unicode_literals, print_function

import pandas as pd
import re
import os.path
import spacy
from os import listdir
import pdfminer
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import BytesIO
from spacy.lang.en import English

# %%
def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = BytesIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr,  laparams=laparams)#codec=codec,
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text.decode("utf-8")

# %%
# #file_path='/home/mehroz/pdf_filed_2/Untitled Folder/Aluminum paper/1-s2.0-S135964541630828X-main.pdf'
# path='/home/mehroz/pdf_filed_2/Untitled Folder/Aluminum paper/'

def preprocess(path):
    

                
                
    nlp = spacy.load("en")
    regex_str=r"corrosion|DoS|(IGC)|intergranular stress corrosion cracking (IGSCC)|yield strength|corrosion rate|hardness|pit initiation rate|pit growth kinetics|electrochemical potentials|potentiodynamic polarisation|stabilisation at open circuit potential (OCP)|(OCP)|(E corr )|(Ecorr)|corrosion density|(i corr )|hardness|recrystallised|intergranular corrosion rate|electrochemical properties|anodic kinetic|corrosion kinetics|gal-vanic corrosion|galvanic corrosion|mechanical properties|degree of sensitisation|relative corrosion potential|sensitisation resistance|tentiodynamic polarisation|intergranular corrosion rate"

    sentencizer = nlp.create_pipe("sentencizer")
    nlp.add_pipe(sentencizer)
    pdf_files=listdir(path)
    compositions_list=[]
    
    
            
#     for indx in range(0,len(partial_list)):
#         remaining_sent=partial_list[indx]
#         x1 = re.finditer(partial_regex,remaining_sent)
#         if x1:
            
#             for match_data in x1:
#                 result=match_data.span()
#                 print('\n remaining matched->',remaining_sent[result[0]:result[1]])
#                 #print('\n',sentence[result[0]:result[1]],'<-sentence-> ',sentence)
#                 r1=(remaining_sent.decode("utf-8"),{"entities":[(remaining_sent[0],remaining_sent[1],"Composition")]})
#                 #print('\n r type :',type(r))
#                 compositions_list.append(r1)
                
    for pdf_file_index in range(0,len(pdf_files)):
        pdf_file_path=path+pdf_files[pdf_file_index]
        print('\n Address :',pdf_file_path)
        
        text_file=convert_pdf_to_txt(pdf_file_path)
        doc = nlp(text_file)
        
        for sent in doc.sents:
            #print('\n ----- ',sent)
            #print('\n --- ',str(sent))
            #print('\n type :',type(sent))
            if re.search('fracture strain',str(sent)):
                print('\n start sent:')
                print(sent)
                print('\n end sent')
    return                     
        #get_compositions(text_file)

# %%
path='/home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/'

compositions=preprocess(path)
# Out:
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509314009319-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1044580317336136-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1003632617601900-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509314014749-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0925838817304140-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S026130691100553X-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509313001275-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0925838817330463-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0749641917306381-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/Roles of Microalloying Elements on the Cluster Formation in the Initial Stage of Phase Decomposition of Al-Based Alloys.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645413009294-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509309004043-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/Orrhede1996_Article_ElasticConstantsAndThermalExpa.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359646214002772-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0925838816319879-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1003632617600335-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509316302313-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S2095034915300088-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509315000738-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509309011368-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0010938X18319164-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1044580318304510-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645414003425-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509316300855-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645414001803-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509316303641-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1003632618646746-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1003632617600906-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0261306911002809-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0924013615300029-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645414007770-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509312002390-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/Sato1999_Article_MicrostructuralEvolutionOf6063.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509315305190-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359646214000074-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/Forging of Discontinuously Reinforced Composites.pdf
#
#  start sent:
#
#
# fracture
#
# The Cockcroft-and-Latham fracture criterion
# proposes that ductile fracture occurs when the
# amount of deformation work due to the max-
# imum tensile stress reaches a critical value C*.
# The criterion is given in Eq 1, where s2B is the
# maximum tensile stress in region B, seff and eeff
# are the effective stress and strain respectively, s
# is the equivalent stress, e is strain, and ef is the
# fracture strain in uniaxial tension.
#
#  end sent
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/Alloying Elements Example- Preaged Al.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645415006837-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509313008769-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645416301239-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S2214785315003776-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/colors.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645416308412-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S135964541630828X-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0749641918302912-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S092150931630082X-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/Enhancement of strength and superplasticity in a 6061_MetTransA.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0925838815304242-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1359645417300599-main.pdf
#
#  start sent:
# Local stirring using a
# friction stir processing (FSP) tool is shown here to very signiﬁcantly increase the fracture strain of the Al
# alloy 6056 sometimes by more than a factor of two while making it more isotropic.
#
#  end sent
#
#  start sent:
# Factors like
# particle clustering, particle morphology and size have a ﬁrst order
# impact on the fracture strain [6,9].
#
#  end sent
#
#  start sent:
# The key element controlling the
# magnitude of the fracture strain in these alloys was the effect of
# particle size distribution and spatial distribution on the void
# nucleation and coalescence process.
#
#  end sent
#
#  start sent:
# The presence of pre-existing
# voids has also been shown to have a ﬁrst order effect on the
# fracture strain.
#
#  end sent
#
#  start sent:
# The
# true fracture strain deﬁned as εf ¼ ln (A0/Af) is determined from
# broken specimens, with A0 and Af being respectively the initial and
# ﬁnal cross-section area.
#
#  end sent
#
#  start sent:
# 13(a) shows, for the BM and for the FSPed material, the
# variation of the fracture strains ( 3 f) as a function of s0 corre-
# sponding to the various heat treatments.
#
#  end sent
#
#  start sent:
# Variation of the (a) true fracture strains and (b) engineering fracture strain
# extracted from the uniaxial tensile tests as a function of the yield stress corresponding
# to the different heat treatments.
#
#  end sent
#
#  start sent:
#
#
# Tensile testing and interrupted tensile tests of BM and FSPed
#
# samples have provided the following key results:
#  The fracture strain of FSP samples is improved by almost 100% in
# the best cases compared to the BM tensile samples at identical
# yield strength.
#
#  end sent
#
#  start sent:
# The
# vertical lines indicate the experimental fracture strain ( 3 f).
#
#  end sent
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1044580314000321-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1044580316308403-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0921509307017790-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S1044580317336781-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0925838818303074-main.pdf
#
#  Address : /home/mehroz/pdf_filed_2/Untitled_Folder/Aluminum paper/1-s2.0-S0264127516313090-main.pdf
